# %% [markdown]
# # Problem 1
# Kullanıcıdan bir sayı alınız. Sayı 0'dan büyükse pozitif , 0'dan küçükse negatif sıfıra eşitse sıfır yazdırınız.

# %%
sayi=int(input("Bir sayi giriniz:"))
if sayi > 0:
    print("Seçtiğiniz sayı pozitif")
elif sayi < 0 :
    print("Seçtiğiniz sayı negatif")
else:
    print("Seçtiğiniz sayı 0 ")
# Out:
# Seçtiğiniz sayı 0

# %% [markdown]
#  # Problem 2
# Kullanıcıdan aldığınız bir sayının mükemmel olup olmadığını bulmaya çalışın.
# Bir sayının kendi hariç bölenlerinin toplamı kendine eşitse bu sayıya "mükemmel sayı" denir. Örnek olarak, 6 mükemmel bir sayıdır. (1 + 2 + 3 = 6)

# %%
müksayi=int(input("Kontrol edilmesini istediğiniz sayıyı giriniz:"))
toplam=0
for i in range (1,müksayi):
    if müksayi % i == 0:
        toplam+=i
if toplam == müksayi:
    print(f"Seçtiğiniz sayı olan {müksayi} mükemmel sayidir kendi hariç bölenleri toplamı da {toplam}a eşittir")
else:
        print("Seçtiğiniz sayı mükemmel sayı değildir")
# Out:
# Seçtiğiniz sayı mükemmel sayı değildir

# %% [markdown]
#  # Problem 3
# Kullanıcıdan aldığınız bir sayının "Armstrong" sayısı olup olmadığını bulmaya çalışın.
# Örnek olarak, Bir sayı eğer 4 basamaklı ise ve oluşturan rakamlardan herbirinin 4. kuvvetinin toplamı( 3 basamaklı sayılar için 3.kuvveti ) o sayıya eşitse bu sayıya "Armstrong" sayısı denir.
#
# Örnek olarak : 1634 = 1^4 + 6^4 + 3^4 + 4^4

# %%
armstrong=(input("Bir sayı giriniz:"))
sum=0
for x in (armstrong):
    sum += int(x)**4
if sum == armstrong:
    print(f"Seçtiğiniz {armstrong} sayısını oluşturan rakamların 4. kuvvetleri toplamı da {sum}a eşit olup sayı armstrong sayıdır")
else:
    print(f"Seçtiğiniz {armstrong} sayısını oluşturan rakamların 4. kuvvetleri toplamı  {sum}a eşit olup sayı armstrong sayı değildir")
# Out:
# Seçtiğiniz 12 sayısını oluşturan rakamların 4. kuvvetleri toplamı  17a eşit olup sayı armstrong sayı değildir

# %% [markdown]
# # Problem 4
# YetGen Core Python mezunu bir öğretmenimiz öğrencilerine 1'den 10'a kadar sayılarla çarpım tablosunu öğretirken Python'dan destek almak istiyor. Bu konuda öğretmenimize yardımcı olmak ister misin?
#
# İpucu: İç içe 2 tane for döngüsü kullanın.
#
# Aynı zamanda sayıları range() fonksiyonunu kullanarak elde edin.

# %%
for m in range (1,10):
    for a in range(1,10):
        print(f"{m}*{a}={m*a}")
# Out:
# 1*1=1
# 1*2=2
# 1*3=3
# 1*4=4
# 1*5=5
# 1*6=6
# 1*7=7
# 1*8=8
# 1*9=9
# 2*1=2
# 2*2=4
# 2*3=6
# 2*4=8
# 2*5=10
# 2*6=12
# 2*7=14
# 2*8=16
# 2*9=18
# 3*1=3
# 3*2=6
# 3*3=9
# 3*4=12
# 3*5=15
# 3*6=18
# 3*7=21
# 3*8=24
# 3*9=27
# 4*1=4
# 4*2=8
# 4*3=12
# 4*4=16
# 4*5=20
# 4*6=24
# 4*7=28
# 4*8=32
# 4*9=36
# 5*1=5
# 5*2=10
# 5*3=15
# 5*4=20
# 5*5=25
# 5*6=30
# 5*7=35
# 5*8=40
# 5*9=45
# 6*1=6
# 6*2=12
# 6*3=18
# 6*4=24
# 6*5=30
# 6*6=36
# 6*7=42
# 6*8=48
# 6*9=54
# 7*1=7
# 7*2=14
# 7*3=21
# 7*4=28
# 7*5=35
# 7*6=42
# 7*7=49
# 7*8=56
# 7*9=63
# 8*1=8
# 8*2=16
# 8*3=24
# 8*4=32
# 8*5=40
# 8*6=48
# 8*7=56
# 8*8=64
# 8*9=72
# 9*1=9
# 9*2=18
# 9*3=27
# 9*4=36
# 9*5=45
# 9*6=54
# 9*7=63
# 9*8=72
# 9*9=81

# %% [markdown]
# # Problem 5
# Markete giren bir YetGen'li sıra beklememek için hızlı kasaya gider. Hızlı kasanın çalışma mantığı şu şekildedir:
# - Kullanıcının aldığı her ürünün fiyatını tek tek girmesi gerekir.
# - Kullanıcı kasadan çıkmak isterse q tuşuna basmalıdır.
# - Kasa girilen fiyatları son fiyat isimli değişkene ekler.
# - Değişkeni ekrana bastırır.
#
# İpucu: while döngüsünü sonsuz koşulla başlatın ve kullanıcı q'ya basarsa döngüyü break ile sonlandırın.

# %%
sonfiyat=0
print("Hızlı kasaya hoş geldiniz")
while True:
    ürün=input("Almak istediğiniz ürünün fiyatını giriniz")
    if ürün=="q":
        break
    sonfiyat += float(ürün)
    print(sonfiyat)
    print("Çıkmak için q tuşuna basınız")
# Out:
# Hızlı kasaya hoş geldiniz
# 2.0
# Çıkmak için q tuşuna basınız
# 5.0
# Çıkmak için q tuşuna basınız

# %% [markdown]
# # Problem 6
# 1'den 100'e kadar olan sayılardan sadece 3'e bölünen sayıları ekrana bastırın. Bu işlemi continue ile yapmaya çalışın.

# %%
for b in range (1,100):
    if b % 3 != 0:
        continue
    elif b % 3 == 0:
        print(b)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99

# %% [markdown]
# # Problem 7
# Bir YetGen Core Python mezunu MEF Üniversitesi'nde Bilgisayar Bilimleri Doktora programının mülakatına girmeye hak kazanıyor. Mülakata hazırlanırken internetten soru araştırıyor. Karşısına çıkan ünlü FizzBuzz sorusuna benzer YetGen sorusunda kendisini yeterince hazır hissetmiyor. Bu soruyu çözmesine destek olmak ister misin?
#
# Soru aşağıdaki gibidir:
#
# 1’den 100’e kadar sayıları yazdırıyoruz. Ancak eğer sayı 3’e bölünüyor ise Yet, sayı 5’e bölünüyorsa Gen, hem 3’e hem 5’e bölünüyorsa YetGen yazdırıyoruz.

# %%
for r in range(1,100):
    if (r % 3 == 0) and (r % 5 != 0):
        print(f"sayı {r} Yet")
    elif (r % 3 != 0) and (r % 5 == 0):
        print(f"sayı {r} Gen")
    elif (r % 3 == 0) and (r % 5 == 0):
        print(f"sayı {r} YetGen")
# Out:
# sayı 3 Yet
# sayı 5 Gen
# sayı 6 Yet
# sayı 9 Yet
# sayı 10 Gen
# sayı 12 Yet
# sayı 15 YetGen
# sayı 18 Yet
# sayı 20 Gen
# sayı 21 Yet
# sayı 24 Yet
# sayı 25 Gen
# sayı 27 Yet
# sayı 30 YetGen
# sayı 33 Yet
# sayı 35 Gen
# sayı 36 Yet
# sayı 39 Yet
# sayı 40 Gen
# sayı 42 Yet
# sayı 45 YetGen
# sayı 48 Yet
# sayı 50 Gen
# sayı 51 Yet
# sayı 54 Yet
# sayı 55 Gen
# sayı 57 Yet
# sayı 60 YetGen
# sayı 63 Yet
# sayı 65 Gen
# sayı 66 Yet
# sayı 69 Yet
# sayı 70 Gen
# sayı 72 Yet
# sayı 75 YetGen
# sayı 78 Yet
# sayı 80 Gen
# sayı 81 Yet
# sayı 84 Yet
# sayı 85 Gen
# sayı 87 Yet
# sayı 90 YetGen
# sayı 93 Yet
# sayı 95 Gen
# sayı 96 Yet
# sayı 99 Yet
