# %% [markdown]
# # Problem 1
#
# Fizikte, bir nesnenin sabit ivmeyle hareket ederken son hızını
# (veya hızını) bulmak için aşağıdaki denklem kullanılabilir:
# ```
# vf = vi + at
# burada:
# vf= son hız
# vi= ilk hız
# a= hızlanma
# t= zaman
# ```
# İlk hız, ivme ve zaman verildiğinde, son hızı döndürecek bir fonksiyon yazın.

# %%
a=float(input("İlk hızı giriniz:"))
b=float(input("ivmeyi giriniz:"))
c=float(input("zamanı giriniz:"))
def sonhizbulma():
    sonhız=a+b*c
    return sonhız
sonhizbulma()
# Out:
# 120.0

# %% [markdown]
# # Problem 2
#
# 1'den 1000'e kadar olan sayılardan mükemmel sayı olanları ekrana yazdırın. Bunun için bir sayının mükemmel olup olmadığını dönen bir tane fonksiyon yazın.
#
# Bir sayının bölenlerinin toplamı kendine eşitse bu sayı mükemmel bir sayıdır. Örnek olarak 6 mükemmel bir sayıdır (1 + 2 + 3 = 6).

# %%
def müksayibul():
    müksayilar=[]
    for sayi in range(1,1001):
        toplam=0
        for i in range(1,sayi):
            if sayi % i ==0:
                toplam+=i
        if toplam == sayi:
            müksayilar.append(sayi)
    return müksayilar
print(müksayibul())
# Out:
# [6, 28, 496]

# %% [markdown]
# # Problem 3
#
# 1'den 100'e kadar olan sayılardan pisagor üçgeni oluşturanları ekrana yazdıran bir fonksiyon yazın.(a <= 100,b <= 100)

# %%
def pisagor():
    kenarlar=[]
    for a in range(1,101):
        for b in range(a,101):
            ckare=(a**2)+(b**2)
            c=int(ckare**0.5)
            if c**2==ckare and c <=100:
                kenarlar.append((a,b,c))
    return kenarlar
kenarlar=pisagor()
for ucgen in kenarlar:
    print(ucgen)
# Out:
# (3, 4, 5)
# (5, 12, 13)
# (6, 8, 10)
# (7, 24, 25)
# (8, 15, 17)
# (9, 12, 15)
# (9, 40, 41)
# (10, 24, 26)
# (11, 60, 61)
# (12, 16, 20)
# (12, 35, 37)
# (13, 84, 85)
# (14, 48, 50)
# (15, 20, 25)
# (15, 36, 39)
# (16, 30, 34)
# (16, 63, 65)
# (18, 24, 30)
# (18, 80, 82)
# (20, 21, 29)
# (20, 48, 52)
# (21, 28, 35)
# (21, 72, 75)
# (24, 32, 40)
# (24, 45, 51)
# (24, 70, 74)
# (25, 60, 65)
# (27, 36, 45)
# (28, 45, 53)
# (28, 96, 100)
# (30, 40, 50)
# (30, 72, 78)
# (32, 60, 68)
# (33, 44, 55)
# (33, 56, 65)
# (35, 84, 91)
# (36, 48, 60)
# (36, 77, 85)
# (39, 52, 65)
# (39, 80, 89)
# (40, 42, 58)
# (40, 75, 85)
# (42, 56, 70)
# (45, 60, 75)
# (48, 55, 73)
# (48, 64, 80)
# (51, 68, 85)
# (54, 72, 90)
# (57, 76, 95)
# (60, 63, 87)
# (60, 80, 100)
# (65, 72, 97)

# %% [markdown]
# # Problem 4
#
# Bir duvar boyamaya karar verdiniz. Boya kutusunun üzerindeki talimatta, 1 kutu boyanın 5 metrekarelik bir duvarı boyayabileceği yazıyor. Rastgele bir duvar yüksekliği ve genişliği verildiğinde, kaç kutu boya satın almanız gerektiğini hesaplayın.
#
# kutu sayısı = (duvar yüksekliği * duvar genişliği) ÷ kutu başına kaplama.
#
# örneğin Yükseklik = 2, Genişlik = 4, Kaplama = 5
#
# kutu sayısı = (2 * 4) ÷ 5 = 1.6
#
# Ancak bir kutu boyanın 0,6'sını satın alamayacağınız için, sonuç 2 kutuya yuvarlanmalıdır .

# %%
dikkenar=int(input("Dik kenarı giriniz:"))
yankenar=int(input("yan kenarı giriniz:"))
def kutusayisibulma():
    gereken=dikkenar*yankenar/5
    return round(gereken)
kutusayisibulma()
# Out:
# 2

# %% [markdown]
# # Problem 5
#
# Bir kelimedeki ünlü ve ünsüz harfleri sayan bir fonksiyon yazınız.

# %%
ünlüler=["a","e","ı","i","o","ö","u","ü"]
def unluunsuz(kelime):
    unlusayısı=0
    unsuzsayısı=0
    for i in (kelime):
        if i in ünlüler:
            unlusayısı += 1
        else:
            unsuzsayısı += 1
    print(f"ünlü sayısı:{unlusayısı}")
    print(f"ünsüz sayısı:{unsuzsayısı}")

kelime="ali"
unluunsuz(kelime)
# Out:
# ünlü sayısı:2
# ünsüz sayısı:1

# %% [markdown]
# # Problem 6
#
# Verilen bir listeden çift sayıları yazdıran bir fonksiyon yazınız.

# %%
liste=[1,4,5,6,7,8,9,11,14,18,25,32,44,51,63,78,82,88,99]
def ciftbulma():
    for i in liste:
        if i %2 ==0:
            print(i)
    return        
ciftbulma()
# Out:
# 4
# 6
# 8
# 14
# 18
# 32
# 44
# 78
# 82
# 88

# %% [markdown]
# # Problem 7
#
# 0'dan 10'a kadar olan sayıların toplamını hesaplayan özyinelemeli (Recursive Function) bir fonksiyon oluşturan bir fonksiyon yazınız.
#
# Özyinelemeli (Recursive Function) bir işlev, kendini tekrar tekrar çağıran bir işlevdir.

# %%
def topla():
    sum=0
    for i in range(1,10):
        sum += i
    return sum
topla()
# Out:
# 45
